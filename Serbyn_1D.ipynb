# %% [markdown]
# # Serbyn calculation in 1D
#
# $$Q(0,0)=-e^2 \frac{1}
#     {2\beta} \sum_{\epsilon_n}\frac{1}{L}\sum_k Tr\left[ v^2 G(k,i\epsilon_n)G(k,i\epsilon_n)\right]$$
#
# $$G(k, i\epsilon_n)=\left[(i\epsilon_n+i\Gamma)\tau_0\sigma_0-\left(2w_0cos(k)-\mu\right)\tau_z\sigma_0+\Delta\tau_y\sigma_y\right]^{-1}$$
# $$\epsilon_n-\epsilon^{(1)}=-\Gamma$$
#
# $$\epsilon_n=\frac{2\pi}{\beta}\left(n+\frac{1}{2}\right)$$
#
# $$\Delta=\Delta^{(1)}$$

# %% [raw]
# ---
# execute:
#     echo: false
# format:
#   html:
#     code-fold: true
#     code-tools: false
#   pdf:
#     code-annotations: false
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from Serbyn_1D import get_Q

# %%
beta = 100
N = 100
epsilon_n = 2*np.pi/beta*(np.arange(N)+1/2)
L = 100
k = 2*np.pi/L*np.arange(0, L)
w_0 = 1
Gamma = 0.01
Delta = np.linspace(-1, 1, 10)
Delta = np.concatenate((Delta[Delta<0], [0], Delta[Delta>0]))
mu = 0

Q_vs_Delta = [get_Q(k, epsilon_n, w_0, Gamma, Delta, mu, beta) for Delta in Delta]

fig, ax  = plt.subplots()
ax.plot(Delta, Q_vs_Delta)
ax.set_xlabel(r"$\Delta$");
ax.set_ylabel(r"$Q(\Delta)$");

# %%
beta = np.linspace(10, 100, 10)
N = 100
L = 100
k = 2*np.pi/L*np.arange(0, L)
w_0 = 1
Gamma = 0.01
Delta = 0
mu = 0

Q_vs_Delta = [get_Q(k, w_0, Gamma, Delta, mu, N, beta) for beta in beta]

fig, ax  = plt.subplots()
ax.plot(beta, Q_vs_Delta)
ax.set_xlabel(r"$\beta$");
ax.set_ylabel(r"$Q(\beta)$");

# %%
beta = 100
N = 100
L = 100
k = 2*np.pi/L*np.arange(0, L)
w_0 = 1
Gamma = 0.01
Delta = 0
mu = np.linspace(0, 3, 10)

Q = [get_Q(k, w_0, Gamma, Delta, mu, N, beta) for mu in mu]

fig, ax  = plt.subplots()
ax.plot(mu, Q)
ax.set_xlabel(r"$\mu$");
ax.set_ylabel(r"$Q(\mu)$");
# Out:
# /home/gabriel/anaconda3/envs/DC-superconductivity/lib/python3.11/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/gabriel/anaconda3/envs/DC-superconductivity/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Q
# Out:
# [(0.19387244933885472-1.0437049267264437e-34j),
#  (0.03619353340547841+2.6504622345529304e-19j),
#  (0.024556703310095743-3.313077793191163e-19j),
#  (0.038376911932766884+9.939233379573489e-20j),
#  (0.030020297506359355+4.969616689786745e-19j),
#  (0.03258254042378255+1.2147951908367597e-18j),
#  (-0.0065029794778902975-1.3252311172764652e-18j),
#  (-0.013511760252237732+4.417437057588218e-19j),
#  (-0.013270518634930112+1.766974823035287e-19j),
#  (-0.01286887132817381-3.9756933518293956e-19j)]
